# %% [markdown]
# 1. Using the R programming language, display the list of all available built-in datasets. Load
# any one dataset from the list and perform Exploratory Data Analysis (EDA) on it. Your
# EDA should include summary statistics and appropriate visualizations to show the data
# distribution.

# %%
data()
data(AirPassengers)
head(AirPassengers)
# Out:
#      Jan Feb Mar Apr May Jun
# 1949 112 118 132 129 121 135

# %%
str(AirPassengers )
summary(AirPassengers)
plot(AirPassengers)
# Out:
#  Time-Series [1:144] from 1949 to 1961: 112 118 132 129 121 135 148 148 136 119 ...
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   104.0   180.0   265.5   280.3   360.5   622.0
# plot without title

# %%
mean(AirPassengers)
median(AirPassengers)
sd(AirPassengers)

hist(AirPassengers,
     main = "Histogram of Air Passengers",
     xlab = "Number of Passengers",
     col = "lightblue",
     border = "black")
# Out:
# [1] 280.2986
# [1] 265.5
# [1] 119.9663
# Plot with title “Histogram of Air Passengers”

# %%
boxplot(AirPassengers,
        main = "Boxplot of Air Passengers",
        col = "lightgreen")
# Out:
# Plot with title “Boxplot of Air Passengers”
